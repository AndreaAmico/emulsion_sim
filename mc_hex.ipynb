# %%
# Public libraries

import glob, os, sys, shutil # system packages
import matplotlib.pyplot as plt
import mpmath as mp


import numpy as np
import pandas as pd
import pickle
import scipy.constants as const
import scipy.ndimage as ndimage
import scipy.optimize as opt
import scipy.signal as signal
import time

# Local libraries
# sys.path.append("./pyLi") # Adds pyLi directory to python modules path.
# import lithium as li
import other as ot
import mplparams

# Loading constants
a0 = const.physical_constants["Bohr radius"][0]
c = const.physical_constants["speed of light in vacuum"][0]
h = const.physical_constants["Planck constant"] [0]
hbar = h/(2*np.pi)
kB = const.physical_constants["Boltzmann constant"][0]
m = 9.9883414 * 10**(-27) # Lithium mass [Kg]
muB = const.physical_constants["Bohr magneton"][0]


# Setting inline plots in notebook
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
if os.name == 'posix':
    # %config InlineBackend.figure_format = 'retina' #retina display settings
    
# Set and create an os independent savepath
save_path = os.sep.join((os.path.expanduser("~"), "Desktop", "jupyter"))
os.makedirs(save_path, exist_ok=True)
mplc = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %% [markdown]
# To make a mp4 movie:
#
# *ffmpeg -r 30 -f image2 -s 432x288 -i pic%05d.png -vcodec libx264 -crf 5  -pix_fmt yuv420p test.mp4*

# %%
SIZE = 25
#np.random.seed(42)

xx = np.arange(SIZE)
trappola = 1-(xx-SIZE/2)**2/(SIZE/2)**2
t1 = (np.random.random(size=(SIZE, SIZE))<(np.ones(shape=(SIZE,SIZE))*trappola[:,None])).astype('int16')
t2 = (np.random.random(size=(SIZE, SIZE))<(np.ones(shape=(SIZE,SIZE))*trappola[:,None])).astype('int16')

state_1 = np.random.choice([0,1,1], size=(SIZE,SIZE)).astype('int16')*t1
state_2 = np.random.choice([0,2,2], size=(SIZE,SIZE)).astype('int16')*t2
initial_state = state_1+state_2

state = initial_state

# %%
class mc(object):
    
    # 0: empty cell
    # 1: state-1 atom
    # 2: state-2 atom
    # 3: state-1 + state-2 atoms
    # 4: molecules
    
    def __init__(self, state):
        self.state = state
        self.SIZE = state.shape[0]
        
        # colors
        c1 = '#ff3e30'
        c2 = '#db3236'
        c2 = '#4885ed'
        c12 = 'yellow'
        cmol = 'black'
        c12 = 'purple'

        self.color_list = ['white', c1, c2, c12, cmol]


        self.even_links = (
            np.array((0, 1)),
            np.array((0, -1)),
            np.array((1, 0)),
            np.array((1, 1)),
            np.array((-1, 0)),
            np.array((-1, 1)))

        self.odd_links = (
            np.array((0, 1)),
            np.array((0, -1)),
            np.array((1, 0)),
            np.array((1, -1)),
            np.array((-1, 0)),
            np.array((-1, -1)))


        self.T=0.2
        self.TRAP_DEPTH = 0.2
        self.FC_REDUCTION = 1
        self.FM_REDUCTION = 1
        self.kFa = 1.3*0.0001
        self.n_mol = 0
        self.update_coefficients()
        
        
        
    def update_coefficients(self):
        
        self.franck_condon = 0.289*148/(6*np.pi**2)**2 * self.kFa**6 / (1+0.5*self.kFa**2) * self.FC_REDUCTION
        self.atom_atom_energy = 4/(3*np.pi)*self.kFa + 2/np.pi**2 * self.kFa**2 * self.FM_REDUCTION

        M0 = 0
        M1 = 1
        M3 = 2
        M4 = 2

        S0 = 0
        S1 = 0
        S3 = self.atom_atom_energy * 6
        S4 = -2/self.kFa**2

        S0x = 0
        S11 = 3/5
        S12 = self.atom_atom_energy
        S13 = 3/5 * self.atom_atom_energy
        S14 = 0.9 * self.atom_atom_energy
        S33 = 6/5 + self.atom_atom_energy
        S34 = 1.8 * self.atom_atom_energy
        S44 = 0.6 * self.atom_atom_energy

        self.S_SELF = [S0, S1, S1, S3, S4]
        self.S_MASS = [M0, M1, M1, M3, M4]

        self.S_MATRIX = [[S0x, S0x, S0x, S0x, S0x],
                        [S0x, S11, S12, S13, S14],
                        [S0x, S12, S11, S13, S14],
                        [S0x, S13, S13, S33, S34],
                        [S0x, S14, S14, S34, S44]]
    
        V00 = [self.nothing]
        V01 = V10 = [self.swap]
        V02 = V20 = [self.swap]
        V03 = V30 = [self.swap, self.ret_12, self.ret_21]
        V04 = V40 = [self.swap]

        V11 = [self.nothing]
        V12 = [self.swap, self.create_double, self.create_mol]
        V13 = [self.swap, self.create_mol]
        V14 = [self.swap, self.dissociate_mol]

        V22 =[self.nothing]
        V21 = V12
        V23 = V13
        V24 = V14

        V31 = [self.swap, self.create_mol_inv]
        V32 = V31
        V33 = [self.create_mol, self.create_2mol]
        V34 = [self.swap, self.create_mol, self.dissociate_mol]

        V41 = [self.swap, self.dissociate_mol_inv]
        V42 = V41
        V43 = [self.swap, self.create_2mol, self.dissociate_mol_inv]
        V44 = [self.dissociate_mol, self.dissociate_mol_inv, self.dissociate_2mol]

        self.V_MATRIX = [[V00, V01, V02, V03, V04],
                        [V01, V11, V12, V13, V14],
                        [V02, V21, V22, V23, V24],
                        [V03, V13, V23, V33, V34],
                        [V04, V14, V24, V34, V44]]
      
        
    
    def nothing(self, s1, s2):
        return s1, s2

    def swap(self, s1, s2):
        return s2, s1

    def ret_12(self, s1, s2):
        return 1, 2

    def ret_21(self, s1, s2):
        return 2, 1

    def create_double(self, s1, s2):
        return 0, 3

    def create_mol(self, s1, s2):
        if np.random.random()<self.franck_condon:
            return s1, 4
        else:
            return s1, s2

    def create_2mol(self, s1, s2):
        if np.sqrt(np.random.random())<self.franck_condon:
            return 4, 4
        else:
            return s1, s2

    def dissociate_mol(self, s1, s2):
        if np.random.random()<self.franck_condon:
            return s1, 3
        else:
            return s1, s2

    def dissociate_2mol(self, s1, s2):
        if np.sqrt(np.random.random())<self.franck_condon:
            return 3, 3
        else:
            return s1, s2

    def create_mol_inv(self, s1, s2):
        if np.random.random()<self.franck_condon:
            return s2, 4
        else:
            return s1, s2

    def dissociate_mol_inv(self, s1, s2):
        if np.random.random()<self.franck_condon:
            return s2, 3
        else:
            return s1, s2


    def get_random_pair(self):
        ij = np.random.randint(self.SIZE, size=2)
        direction = np.random.randint(6)
        step = self.odd_links[direction] if ij[0]%2 else self.even_links[direction]
        return ij, (ij+step)%self.SIZE


    def on_site(self, ij):
        s = self.state[ij[0], ij[1]]
        trap_energy = ((ij[0]-self.SIZE/2)**2 / (self.SIZE/2)**2) * s * self.TRAP_DEPTH
        local_energy = self.S_SELF[s]  
        return trap_energy + local_energy

    def off_site(self, ij):
        e = 0
        s1 = self.state[ij[0], ij[1]]

        ij_links = [(ij+link)%SIZE for link in self.odd_links] if ij[0]%2 else [(ij+link)%SIZE for link in self.even_links]
        for ij2 in ij_links:
            e += self.S_MATRIX[s1][self.state[ij2[0], ij2[1]]]
        return e

    def duplicate_energy(self, p):
        s1 = self.state[p[0][0], p[0][1]]
        s2 = self.state[p[1][0], p[1][1]]
        return self.S_MATRIX[s1][s2]


    def energy_diff(self, p):
        self.i1 = self.state[p[0][0], p[0][1]]
        self.i2 = self.state[p[1][0], p[1][1]]
        initial_energy = (self.on_site(p[0]) + self.on_site(p[1]) + self.off_site(p[0]) + 
                          self.off_site(p[1]) - self.duplicate_energy(p))
        
        f1, f2 = np.random.choice(self.V_MATRIX[self.i1][self.i2])(self.i1, self.i2)
        self.state[p[0][0], p[0][1]] = f1
        self.state[p[1][0], p[1][1]] = f2
        final_energy = (self.on_site(p[0]) + self.on_site(p[1]) + self.off_site(p[0]) + 
                        self.off_site(p[1]) - self.duplicate_energy(p))
        return final_energy - initial_energy

    def mc_step(self):
        p = self.get_random_pair()
        de = self.energy_diff(p)

        if de<=0:
            pass
            #self.swap_states(s, final)
            #self.T = self.T - self.MOLECOLA() * n_mol_created / self.N_tot   ##Update TEMPERATURE
        else:
            if np.random.random() < np.exp(-de/self.T):
                pass
                #self.swap_states(s, final)
                #self.T = self.T - self.MOLECOLA() * n_mol_created / self.N_tot   ##Update TEMPERATURE
            else:
                self.state[p[0][0], p[0][1]] = self.i1
                self.state[p[1][0], p[1][1]] = self.i2
                
    def plot_state(self, rel_time=0, save_plot=False, save_index=0, save_folder=0, save_name='mc', kFa_max=2):
        with plt.rc_context(mplparams.single_column):
            fig = plt.figure(figsize=[s/25.5 for s in (45,45)], dpi=200)  # pdi of the screen to show
                                                                          # the real size of the plot
            ax = fig.add_axes([0, 0.18, 0.9, 0.8]) # set the axes to be the full size of the figure
            ax.axes.get_xaxis().set_visible(False)
            ax.axes.get_yaxis().set_visible(False)
            
            for state_type in range(5):
                x, y = [coord.astype(float) for coord in np.where(self.state==state_type)]
                x[y%2==0] = x[y%2==0] + 0.5
                ax.scatter(x, y,s=18, zorder=5, marker='h', color=self.color_list[state_type])

            ax_bar = fig.add_axes([0, 0.1, 0.6, 0.05]) # set the axes to be the full size of the figure
            ax_bar.barh(1, self.kFa/kFa_max, align='center', color='black')
            ax_bar.set_xlim(0, 1)
            ax_bar.axes.get_xaxis().set_visible(False)
            ax_bar.axes.get_yaxis().set_visible(False)
            ax_bar.annotate('k$_F$a  =  {:.1f}'.format(self.kFa), xy=(1, 1), xytext=(1.05,0.8))
            
            ax_bar_time = fig.add_axes([0, 0.05, 0.6, 0.05]) # set the axes to be the full size of the figure
            ax_bar_time.barh(1, rel_time, align='center', color='black')
            ax_bar_time.set_xlim(0, 1)
            ax_bar_time.axes.get_xaxis().set_visible(False)
            ax_bar_time.axes.get_yaxis().set_visible(False)
            ax_bar_time.annotate('time = {:.2f}'.format(rel_time), xy=(1, 1), xytext=(1.05,0.8))
            
            
            

            if save_plot:
                fig.savefig('{}/{}_{:05}.png'.format(save_folder, save_name, save_index), bbox_inches="tight")
                plt.close()

# %%
def init_state(SIZE=20):
    state_1 = np.random.choice([0,1], size=(SIZE,SIZE)).astype('int16')#*t1
    state_2 = np.random.choice([0,2], size=(SIZE,SIZE)).astype('int16')#*t2
    initial_state = state_1+state_2
    s = mc(initial_state)

    s.T=0.2
    s.TRAP_DEPTH = 0.2
    s.FC_REDUCTION = 0
    s.kFa = 0.001
    s.update_coefficients()
    return s
SIZE=20
s = init_state()

s.plot_state(rel_time=0.3)

# %%
if os.name == 'nt':
    nas_path = '\\\\LITIO6SERVER\\Measurements\\Emulsion\\mc\\mc_mix7'
else:
    nas_path = '/Volumes/Measurements/Emulsion/mc/mc_mix7'
os.makedirs(nas_path, exist_ok=True)


TOTAL_STEPS = 5e4
PLOT_PERIOD = 100
KFA_MAX = 1.5
index = 0

# INIT STATE
s = init_state()
s.T = 0.2
s.TRAP_DEPTH = 0.2
s.FC_REDUCTION = 1.3
s.FM_REDUCTION = 1
s.kFa = 0.001
s.update_coefficients()

def mappa(perc, i, f, bottom, top):
    rel_perc = (perc - bottom) / (top - bottom)
    return (f - i) * rel_perc + i

def experiment(i, total_steps=TOTAL_STEPS, s=s):
    perc = i/total_steps
    ############################################################
    if  perc < 0.20:
        s.kFa = 0.001
    ############################################################
    elif 0.18 < perc < 0.3:
        s.kFa = mappa(perc, 0.001, 1.5, 0.2, 0.3)
    ############################################################
    else:
        s.kFa = 1.5
    s.update_coefficients()
    

for i in range(int(TOTAL_STEPS)):
    s.mc_step()
    
    if not i%PLOT_PERIOD:
        s.plot_state(rel_time=i/TOTAL_STEPS, save_plot=True, save_index=index,
                     save_folder=nas_path, save_name='mc', kFa_max=KFA_MAX)
        index += 1
        experiment(i, TOTAL_STEPS, s)
        ot.progress_bar(i, TOTAL_STEPS)
# Out:
# [##################################################] 100.0%

# %%
if os.name == 'nt':
    nas_path = '\\\\LITIO6SERVER\\Measurements\\Emulsion\\mc\\mc_no_mol7'
else:
    nas_path = '/Volumes/Measurements/Emulsion/mc/mc_no_mol7'
os.makedirs(nas_path, exist_ok=True)

TOTAL_STEPS = 5e4
PLOT_PERIOD = 100
KFA_MAX = 1.5
index = 0

# INIT STATE
s = init_state()
s.T=0.2
s.TRAP_DEPTH = 0.2
s.FC_REDUCTION = 0
s.FM_REDUCTION = 1
s.kFa = 0.001
s.update_coefficients()

def mappa(perc, i, f, bottom, top):
    rel_perc = (perc - bottom) / (top - bottom)
    return (f - i) * rel_perc + i

def experiment(i, total_steps=TOTAL_STEPS, s=s):
    perc = i/total_steps
    ############################################################
    if  perc < 0.2:
        s.kFa = 0.001
    ############################################################
    elif 0.18 < perc < 0.4:
        s.kFa = mappa(perc, 0.001, 1.5, 0.2, 0.4)
    ############################################################
    else:
        s.kFa = 1.5
    s.update_coefficients()
    

for i in range(int(TOTAL_STEPS)):
    s.mc_step()
    
    if not i%PLOT_PERIOD:
        s.plot_state(rel_time=i/TOTAL_STEPS, save_plot=True, save_index=index,
                     save_folder=nas_path, save_name='mc', kFa_max=KFA_MAX)
        index += 1
        experiment(i, TOTAL_STEPS, s)
        ot.progress_bar(i, TOTAL_STEPS)
# Out:
# [##################################################] 100.0%

# %%
if os.name == 'nt':
    nas_path = '\\\\LITIO6SERVER\\Measurements\\Emulsion\\mc\\mc_no_fm7'
else:
    nas_path = '/Volumes/Measurements/Emulsion/mc/mc_no_fm7'
os.makedirs(nas_path, exist_ok=True)

TOTAL_STEPS = 5e4
PLOT_PERIOD = 100
KFA_MAX = 1.5
index = 0

# INIT STATE
s = init_state()
s.T=0.2
s.TRAP_DEPTH = 0.2
s.FC_REDUCTION = 5
s.FM_REDUCTION = 0
s.kFa = 0.001
s.update_coefficients()

def mappa(perc, i, f, bottom, top):
    rel_perc = (perc - bottom) / (top - bottom)
    return (f - i) * rel_perc + i


def experiment(i, total_steps=TOTAL_STEPS, s=s):
    perc = i/total_steps
    ############################################################
    if  perc < 0.2:
        s.kFa = 0.001
    ############################################################
    elif 0.18 < perc < 0.4:
        s.kFa = mappa(perc, 0.001, 1.5, 0.2, 0.4)
    ############################################################
    else:
        s.kFa = 1.5
    s.update_coefficients()
    

for i in range(int(TOTAL_STEPS)):
    s.mc_step()
    
    if not i%PLOT_PERIOD:
        s.plot_state(rel_time=i/TOTAL_STEPS, save_plot=True, save_index=index,
                     save_folder=nas_path, save_name='mc', kFa_max=KFA_MAX)
        index += 1
        experiment(i, TOTAL_STEPS, s)
        ot.progress_bar(i, TOTAL_STEPS)
# Out:
# [##################################################] 100.0%

# %%
# # 0: empty cell
# # 1: state-1 atom
# # 2: state-2 atom
# # 3: state-1 + state-2 atoms
# # 4: molecules
        
        
# even_links = (
#     np.array((0, 1)),
#     np.array((0, -1)),
#     np.array((1, 0)),
#     np.array((1, 1)),
#     np.array((-1, 0)),
#     np.array((-1, 1)))

# odd_links = (
#     np.array((0, 1)),
#     np.array((0, -1)),
#     np.array((1, 0)),
#     np.array((1, -1)),
#     np.array((-1, 0)),
#     np.array((-1, -1)))


# T=0.2
# TRAP_DEPTH = 0.2
# FC_REDUCTION = 0
# kFa = 1.3*0.0001

# franck_condon = 0.289*148/(6*np.pi**2)**2 * kFa**6 / (1+0.5*kFa**2) * FC_REDUCTION
# atom_atom_energy = 4/(3*np.pi)*kFa + 2/np.pi**2 * kFa**2
# M0 = 0
# M1 = 1
# M3 = 2
# M4 = 2

# S0 = 0
# S1 = 0
# S3 = atom_atom_energy * 6
# S4 = -2/kFa**2

# S0x = 0
# S11 = 3/5
# S12 = atom_atom_energy
# S13 = 3/5 * atom_atom_energy
# S14 = 0.9 * atom_atom_energy
# S33 = 6/5 + atom_atom_energy
# S34 = 1.8 * atom_atom_energy
# S44 = 0.6 * atom_atom_energy

# S_SELF = [S0, S1, S1, S3, S4]
# S_MASS = [M0, M1, M1, M3, M4]

# S_MATRIX = [[S0x, S0x, S0x, S0x, S0x],
#             [S0x, S11, S12, S13, S14],
#             [S0x, S12, S11, S13, S14],
#             [S0x, S13, S13, S33, S34],
#             [S0x, S14, S14, S34, S44]]

# def update_s_matrix():
#     global S_SELF, S_MASS, S_MATRIX, franck_condon, atom_atom_energy, kFa
#     franck_condon = 0.289*148/(6*np.pi**2)**2 * kFa**6 / (1+0.5*kFa**2) * FC_REDUCTION
#     atom_atom_energy = 4/(3*np.pi)*kFa + 2/np.pi**2 * kFa**2
#     S3 = atom_atom_energy * 6
#     S4 = -2/kFa**2

#     S0x = 0
#     S11 = 3/5
#     S12 = atom_atom_energy
#     S13 = 3/5 * atom_atom_energy
#     S14 = 0.9 * atom_atom_energy
#     S33 = 6/5 + atom_atom_energy
#     S34 = 1.8 * atom_atom_energy
#     S44 = 0.6 * atom_atom_energy

#     S_SELF = [S0, S1, S1, S3, S4]
#     S_MASS = [M0, M1, M1, M3, M4]

#     S_MATRIX = [[S0x, S0x, S0x, S0x, S0x],
#                 [S0x, S11, S12, S13, S14],
#                 [S0x, S12, S11, S13, S14],
#                 [S0x, S13, S13, S33, S34],
#                 [S0x, S14, S14, S34, S44]]

# nmol=0
# def nothing(s1, s2):
#     return s1, s2

# def swap(s1, s2):
#     return s2, s1

# def ret_12(s1, s2):
#     return 1, 2

# def ret_21(s1, s2):
#     return 2, 1

# def create_double(s1, s2):
#     return 0, 3

# def create_mol(s1, s2):
#     if np.random.random()<franck_condon:
#         return s1, 4
#     else:
#         return s1, s2
    
# def create_2mol(s1, s2):
#     if np.sqrt(np.random.random())<franck_condon:
#         return 4, 4
#     else:
#         return s1, s2
    
# def dissociate_mol(s1, s2):
#     if np.random.random()<franck_condon:
#         return s1, 3
#     else:
#         return s1, s2
    
# def dissociate_2mol(s1, s2):
#     if np.sqrt(np.random.random())<franck_condon:
#         return 3, 3
#     else:
#         return s1, s2
    
# def create_mol_inv(s1, s2):
#     if np.random.random()<franck_condon:
#         return s2, 4
#     else:
#         return s1, s2
    
# def dissociate_mol_inv(s1, s2):
#     if np.random.random()<franck_condon:
#         return s2, 3
#     else:
#         return s1, s2

    
        
# V00 = [nothing]
# V01 = V10 = [swap]
# V02 = V20 = [swap]
# V03 = V30 = [swap, ret_12, ret_21]
# V04 = V40 = [swap]

# V11 = [nothing]
# V12 = [swap, create_double, create_mol]
# V13 = [swap, create_mol]
# V14 = [swap, dissociate_mol]

# V22 =[nothing]
# V21 = V12
# V23 = V13
# V24 = V14

# V31 = [swap, create_mol_inv]
# V32 = V31
# V33 = [create_mol, create_2mol]
# V34 = [swap, create_mol, dissociate_mol]

# V41 = [swap, dissociate_mol_inv]
# V42 = V41
# V43 = [swap, create_2mol, dissociate_mol_inv]
# V44 = [dissociate_mol, dissociate_mol_inv, dissociate_2mol]

# V_MATRIX = [[V00, V01, V02, V03, V04],
#             [V01, V11, V12, V13, V14],
#             [V02, V21, V22, V23, V24],
#             [V03, V13, V23, V33, V34],
#             [V04, V14, V24, V34, V44]]


# def get_random_pair():
#     ij = np.random.randint(SIZE, size=2)
#     direction = np.random.randint(6)
#     step = odd_links[direction] if ij[0]%2 else even_links[direction]
#     return ij, (ij+step)%SIZE


# def on_site(ij):
#     s = state[ij[0], ij[1]]
#     trap_energy = ((ij[0]-SIZE/2)**2 / (SIZE/2)**2) * s * TRAP_DEPTH
#     local_energy = S_SELF[s]  
#     return trap_energy + local_energy

# def off_site(ij):
#     e = 0
#     s1 = state[ij[0], ij[1]]
    
#     ij_links = [(ij+link)%SIZE for link in odd_links] if ij[0]%2 else [(ij+link)%SIZE for link in even_links]
#     for ij2 in ij_links:
#         e += S_MATRIX[s1][state[ij2[0], ij2[1]]]
#     return e

# def duplicate_energy(p):
#     s1 = state[p[0][0], p[0][1]]
#     s2 = state[p[1][0], p[1][1]]
#     return S_MATRIX[s1][s2]


# def try_step(p):
#     i1 = state[p[0][0], p[0][1]]
#     i2 = state[p[1][0], p[1][1]]


# def energy_diff(p):
#     i1 = state[p[0][0], p[0][1]]
#     i2 = state[p[1][0], p[1][1]]
#     initial_energy = on_site(p[0]) + on_site(p[1]) + off_site(p[0]) + off_site(p[1]) - duplicate_energy(p)
#     f1, f2 = np.random.choice(V_MATRIX[i1][i2])(i1, i2)
#     state[p[0][0], p[0][1]] = f1
#     state[p[1][0], p[1][1]] = f2
#     final_energy = on_site(p[0]) + on_site(p[1]) + off_site(p[0]) + off_site(p[1]) - duplicate_energy(p)
#     return final_energy - initial_energy

# def mc_step():
#     p = get_random_pair()
#     i1 = state[p[0][0], p[0][1]]
#     i2 = state[p[1][0], p[1][1]]

#     de = energy_diff(p)
    
#     if de<=0:
#         pass
#         #self.swap_states(s, final)
#         #self.T = self.T - self.MOLECOLA() * n_mol_created / self.N_tot   ##Update TEMPERATURE
#     else:
#         if np.random.random() < np.exp(-de/T):
#             pass
#             #self.swap_states(s, final)
#             #self.T = self.T - self.MOLECOLA() * n_mol_created / self.N_tot   ##Update TEMPERATURE
#         else:
#             state[p[0][0], p[0][1]] = i1
#             state[p[1][0], p[1][1]] = i2

# %%
# np.random.seed(int(time.time()))
# i1, i2 = 4, 4

# aa, bb = [], []
# for i in range(1000):
#     a, b = np.random.choice(V_MATRIX[i1][i2])(i1, i2)
#     aa.append(a)
#     bb.append(b)

# fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10,3))
# bins = np.arange(0,6, 1)-0.5
# ax1.hist(aa, bins, density=True)
# ax2.hist(bb, bins, density=True);

# %%
def plot_state():
    with plt.rc_context(mplparams.single_column):
        fig = plt.figure(figsize=[s/25.5 for s in (45,45)], dpi=200)  # pdi of the screen to show
                                                                      # the real size of the plot
        ax = fig.add_axes([0, 0.18, 0.9, 0.8]) # set the axes to be the full size of the figure
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        ax.set_title('kFa = {:.1f}'.format(kFa))
        for i in range(SIZE):
            s = 0 if i%2 else 0.5
            for j in range(SIZE):
                ax.scatter(j+s, i, color=color_list[state[i, j]],  s=18*(20/SIZE)**2, zorder=5, marker='h')
        
        ax_bar = fig.add_axes([0, 0.1, 0.9, 0.05]) # set the axes to be the full size of the figure
        ax_bar.barh(1, 0.5, align='center', color='black')
        ax_bar.set_xlim(0,1.5)
        ax_bar.axes.get_xaxis().set_visible(False)
        ax_bar.axes.get_yaxis().set_visible(False)
                
if os.name == 'nt':
    nas_path = '\\\\150.217.156.104\\Measurements\\Emulsion\\mc\\mc1'
else:
    nas_path = '/Volumes/Measurements/Emulsion/mc/mc1'
    
def save_plot(index):
    with plt.rc_context(mplparams.single_column):
        fig = plt.figure(figsize=[s/25.5 for s in (45,45)], dpi=200)  # pdi of the screen to show
                                                                      # the real size of the plot
        ax = fig.add_axes([0,0,1,1]) # set the axes to be the full size of the figure
        ax.axes.get_xaxis().set_visible(False)
        ax.axes.get_yaxis().set_visible(False)
        ax.set_title('kFa = {:.1f}'.format(kFa))
        for i in range(SIZE):
            s = 0 if i%2 else 0.5
            for j in range(SIZE):
                ax.scatter(j+s, i, color=color_list[state[i, j]],  s=25*(20/SIZE)**2, zorder=5, marker='h')
        fig.savefig(nas_path + '/mc_{:05}.png'.format(index))
        plt.close()
save_path
plot_state()

# %%
'{:04}'.format(13)
# Out:
# '0013'

# %%
SIZE = 20
# xx = np.arange(SIZE)
# trappola = 1-(xx-SIZE/2)**2/(SIZE/2)**2
# t1 = (np.random.random(size=(SIZE, SIZE))<(np.ones(shape=(SIZE,SIZE))*trappola[:,None])).astype('int16')
# t2 = (np.random.random(size=(SIZE, SIZE))<(np.ones(shape=(SIZE,SIZE))*trappola[:,None])).astype('int16')

state_1 = np.random.choice([0,1], size=(SIZE,SIZE)).astype('int16')#*t1
state_2 = np.random.choice([0,2], size=(SIZE,SIZE)).astype('int16')#*t2
initial_state = state_1+state_2

state = initial_state

kFa=0
plot_state()

# %%
N_STEPS = 50000
T = 0.2
kFa = 0


for i in range(N_STEPS):
    mc_step()
    if i%int(N_STEPS/100)==0:
        if i%int(N_STEPS/100)> 0.5:
            kFa=0
        ot.progress_bar(i, N_STEPS)
        #save_plot(int(i/(N_STEPS/100)))

plot_state()
# Out:
# [##################################################] 100.0%

# %%
# Out:
# 6

# %%
p = get_random_pair()
ij_1, ij_2 = p

ii, jj = [np.array(k) for k in zip(ij_1, ij_2)]

fig, [ax1, ax2] = plt.subplots(1, 2, figsize=(10,4))
G_SIZE=SIZE

for i in range(SIZE):
    for j in range(SIZE):
        ax1.scatter(j, i, color=color_list[state[i, j]], s=100, zorder=5)


ax1.plot(jj, ii, linewidth=4, color=mplc[1], alpha=0.5)
ax1.scatter(jj[0], ii[0], color=mplc[1], zorder=10)
ax1.scatter(jj[1], ii[1], color=mplc[2], zorder=10)


p_links = [[(pi+link)%SIZE for link in odd_links] if pi[0]%2 else [(pi+link)%SIZE for link in even_links]
           for pi in p]

for p_num in [0,1]:
    for pi in p_links[p_num]:
        x = pi#shift(pi)
        o = p[p_num]#shift(p[p_num])
        ax1.scatter(x[1], x[0], color=mplc[p_num+1], zorder=2, alpha=0.6, s=300)
        ax1.plot([o[1], x[1]], [o[0], x[0]], color=mplc[p_num+1], linewidth=4, alpha=0.6)   
    
def shift(ij):
    ij = ij%SIZE
    shift = -(ij[0]%2 -1)/2
    return (ij + np.array([0, shift]))%SIZE

    
for i in range(SIZE):
    s = 0 if i%2 else 0.5
    for j in range(SIZE):
        ax2.scatter(j+s, i, color=color_list[state[i, j]],  s=400, zorder=5, marker='h')


        
ij_1s = shift(ij_1)
ij_2s = shift(ij_2)
ax2.scatter(ij_1s[1], ij_1s[0], color='white', zorder=20, marker='o', s=100)
ax2.scatter(ij_2s[1], ij_2s[0], color='black', zorder=20, marker='o', s=100)

for p_num in [0,1]:
    for pi in p_links[p_num]:
        x = shift(pi)
        o = shift(p[p_num])
        #ax2.scatter(x[1], x[0], color=mplc[p_num+1], zorder=2, alpha=0.6, s=450, marker='h')
        ax2.plot([o[1], x[1]], [o[0], x[0]], color=mplc[p_num+1], linewidth=4, alpha=0.9, zorder=4)
